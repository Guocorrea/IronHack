# %% [markdown]
# # Shark Attack Project

# %% [markdown]
# ## Objetivo do Projeto:
#     - Fazer uma análise descritiva dos ataques de tubarões nos últimos 20 anos no mundo.

# %% [markdown]
# # Baixando e analisando o arquivo:
# --------------------------------------------------------------------------------------------
# ## Baixar e dar uma olhada no arquivo do Kaggle sobre ataques de tubarão.

# %%
import pandas as pd
import numpy as np

# %%
atck_full= pd.read_csv('Datas/attacks.csv')
atck_full.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
atck_full
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson�McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
atck_full.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
atck_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Qual arquivo estou usando?
# O arquivo disponível no Kaggle está desatualizado. No site Global Shark Attack tem um arquivo XLS que está com os dados tão sujos quanto o do Kaggle, porém, com mais informações. Isso torna o resultado final do trabalho mais fidedigno. Vou utilizar o arquivo xls daqui para frente!

# %%
atck_xls = pd.read_excel('Datas/GSAF5.xls')

# %% [markdown]
# ## Comparativo dos dados disponíveis no arquivo do Kaggle comparado ao do site:

# %%
atck_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
atck_xls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25827 entries, 0 to 25826
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8805 non-null   object
#  1   Date                    6700 non-null   object
#  2   Year                    6698 non-null   float64
#  3   Type                    6685 non-null   object
#  4   Country                 6650 non-null   object
#  5   Area                    6228 non-null   object
#  6   Location                6146 non-null   object
#  7   Activity                6131 non-null   object
#  8   Name                    6485 non-null   object
#  9   Sex                     6126 non-null   object
#  10  Age                     3769 non-null   object
#  11  Injury                  6668 non-null   object
#  12  Fatal (Y/N)             6147 non-null   object
#  13  Time                    3245 non-null   object
#  14  Species                 3684 non-null   object
#  15  Investigator or Source  6681 non-null   object
#  16  pdf                     6699 non-null   object
#  17  href formula            6696 non-null   object
#  18  href                    6698 non-null   object
#  19  Case Number.1           6699 non-null   object
#  20  Case Number.2           6699 non-null   object
#  21  original order          6700 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
atck_xls
# Out:
#         Case Number         Date    Year        Type  \
# 0        2021.09.10  10-Sep-2021  2021.0         NaN
# 1        2021.09.09  09-Sep-2021  2021.0  Unprovoked
# 2        2021.09.05  05-Sep-2021  2021.0  Unprovoked
# 3      2021.09.03.b  03-Sep-2021  2021.0  Unprovoked
# 4        2021.08.28  28-Aug-2021  2021.0  Unprovoked
# ...             ...          ...     ...         ...
# 25822           NaN          NaN     NaN         NaN
# 25823           NaN          NaN     NaN         NaN
# 25824           NaN          NaN     NaN         NaN
# 25825           NaN          NaN     NaN         NaN
# 25826            xx          NaN     NaN         NaN
#
#                           Country              Area  \
# 0                           EGYPT               NaN
# 1                             USA           Florida
# 2                       AUSTRALIA   New South Wales
# 3      British Overseas Territory  Turks and Caicos
# 4                             USA             Texas
# ...                           ...               ...
# 25822                         NaN               NaN
# 25823                         NaN               NaN
# 25824                         NaN               NaN
# 25825                         NaN               NaN
# 25826                         NaN               NaN
#
#                                  Location         Activity              Name  \
# 0                      Sidi Abdel Rahmen          Swimming           Mohamed
# 1             Ponce Inlet, Volusia County          Surfing     Doyle Neilsen
# 2                           Emerald Beach          Surfing  Timothy Thompson
# 3                                     NaN              NaN              male
# 4      Galveston Island, Galveston County  Boogie boarding              male
# ...                                   ...              ...               ...
# 25822                                 NaN              NaN               NaN
# 25823                                 NaN              NaN               NaN
# 25824                                 NaN              NaN               NaN
# 25825                                 NaN              NaN               NaN
# 25826                                 NaN              NaN               NaN
#
#       Sex   ...               Species   \
# 0        M  ...  No shark invovlement
# 1        M  ...                    NaN
# 2        M  ...            White xhark
# 3        M  ...                    NaN
# 4        M  ...                    NaN
# ...    ...  ...                    ...
# 25822  NaN  ...                    NaN
# 25823  NaN  ...                    NaN
# 25824  NaN  ...                    NaN
# 25825  NaN  ...                    NaN
# 25826  NaN  ...                    NaN
#
#                                  Investigator or Source  \
# 0                               Dr. M. Fouda & M. Salrm
# 1                 Daytona Beach News-Journal, 9/14/2021
# 2                                        B. Myatt, GSAF
# 3                                             Anonymous
# 4      T. Craig, GSAF  & K. McMurray, TrackingShark.com
# ...                                                 ...
# 25822                                               NaN
# 25823                                               NaN
# 25824                                               NaN
# 25825                                               NaN
# 25826                                               NaN
#
#                                 pdf  \
# 0            2021.09.10-Mohamed.pdf
# 1            2021.09.09-Neilsen.pdf
# 2           2021.09.05-Thompson.pdf
# 3      2021.09.03.b-TurksCaicos.pdf
# 4         2021.08.28.-Galveston.pdf
# ...                             ...
# 25822                           NaN
# 25823                           NaN
# 25824                           NaN
# 25825                           NaN
# 25826                           NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25822                                                NaN
# 25823                                                NaN
# 25824                                                NaN
# 25825                                                NaN
# 25826                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.10
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.09
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.05
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...  2021.09.03.b
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2021.08.28
# ...                                                  ...           ...
# 25822                                                NaN           NaN
# 25823                                                NaN           NaN
# 25824                                                NaN           NaN
# 25825                                                NaN           NaN
# 25826                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2021.09.10         6700.0         NaN         NaN
# 1        2021.09.09         6699.0         NaN         NaN
# 2        2021.09.05         6698.0         NaN         NaN
# 3      2021.09.03.b         6697.0         NaN         NaN
# 4        2021.08.28         6696.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25822           NaN            NaN         NaN         NaN
# 25823           NaN            NaN         NaN         NaN
# 25824           NaN            NaN         NaN         NaN
# 25825           NaN            NaN         NaN         NaN
# 25826           NaN            NaN         NaN         NaN
#
# [25827 rows x 24 columns]

# %% [markdown]
# # Limpando os dados:
# ---------------------------------------------------------------------------------------------
#
# ## Ver tudo o que tem no arquivo e começar a limpeza dos dados.

# %%
for column in atck_xls:
    if atck_xls[column].dtypes.type == np.object_:
        print(atck_xls[column].describe())
# Out:
# count     8805
# unique    6680
# top          0
# freq      2106
# Name: Case Number, dtype: int64
# count     6700
# unique    5791
# top       1957
# freq         9
# Name: Date, dtype: int64
# count           6685
# unique            10
# top       Unprovoked
# freq            4908
# Name: Type, dtype: object
# count     6650
# unique     217
# top        USA
# freq      2428
# Name: Country, dtype: object
# count        6228
# unique        864
# top       Florida
# freq         1128
# Name: Area, dtype: object
# count                                 6146
# unique                                4347
# top       New Smyrna Beach, Volusia County
# freq                                   185
# Name: Location, dtype: object
# count        6131
# unique       1563
# top       Surfing
# freq         1072
# Name: Activity, dtype: object
# count     6485
# unique    5520
# top       male
# freq       625
# Name: Name, dtype: object
# count     6126
# unique       7
# top          M
# freq      5401
# Name: Sex , dtype: object
# count     3769
# unique     239
# top         19
# freq        89
# Name: Age, dtype: int64
# count      6668
# unique     3953
# top       FATAL
# freq        838
# Name: Injury, dtype: object
# count     6147
# unique      11
# top          N
# freq      4634
# Name: Fatal (Y/N), dtype: object
# count          3245
# unique          394
# top       Afternoon
# freq            205
# Name: Time, dtype: object
# count            3684
# unique           1631
# top       White shark
# freq              185
# Name: Species , dtype: object
# count                                6681
# unique                               5133
# top       K. McMurray, TrackingSharks.com
# freq                                  118
# Name: Investigator or Source, dtype: object
# count                              6699
# unique                             6689
# top       1923.00.00.a-NJ fisherman.pdf
# freq                                  2
# Name: pdf, dtype: object
# count                                                  6696
# unique                                                 6686
# top       http://sharkattackfile.net/spreadsheets/pdf_di...
# freq                                                      2
# Name: href formula, dtype: object
# count                                                  6698
# unique                                                 6680
# top       http://sharkattackfile.net/spreadsheets/pdf_di...
# freq                                                      4
# Name: href, dtype: object
# count           6699
# unique          6679
# top       2021.07.04
# freq               2
# Name: Case Number.1, dtype: object
# count             6699
# unique            6680
# top       1920.00.00.b
# freq                 2
# Name: Case Number.2, dtype: object
# count                1
# unique               1
# top       stopped here
# freq                 1
# Name: Unnamed: 22, dtype: object
# count                   2
# unique                  2
# top       change filename
# freq                    1
# Name: Unnamed: 23, dtype: object

# %% [markdown]
# ### Criando um DataFrame com as colunas que tem dados descritivos de interesse.

# %%
atck = (atck_xls['Year'], atck_xls['Type'], atck_xls['Country'], atck_xls['Area'],
        atck_xls['Activity'],atck_xls['Sex '], atck_xls['Age'], atck_xls['Injury'],
        atck_xls['Fatal (Y/N)'], atck_xls['Time'], atck_xls['Species '])

# %%
atck = pd.DataFrame(atck)
atck = atck.transpose()
atck.head()
# Out:
#      Year        Type                     Country              Area  \
# 0  2021.0         NaN                       EGYPT               NaN
# 1  2021.0  Unprovoked                         USA           Florida
# 2  2021.0  Unprovoked                   AUSTRALIA   New South Wales
# 3  2021.0  Unprovoked  British Overseas Territory  Turks and Caicos
# 4  2021.0  Unprovoked                         USA             Texas
#
#           Activity Sex   Age  \
# 0         Swimming    M  NaN
# 1          Surfing    M   !6
# 2          Surfing    M   31
# 3              NaN    M  NaN
# 4  Boogie boarding    M   !!
#
#                                               Injury Fatal (Y/N)   Time  \
# 0           Laceration to arm caused by metal object         NaN    NaN
# 1                          Minor injury to right arm           N  13h20
# 2                                              FATAL           Y  10h30
# 3                                       Wrist bitten           N    NaN
# 4  Lacerations both sides of lower leg immediatel...           N  11h45
#
#                 Species
# 0  No shark invovlement
# 1                    NaN
# 2            White xhark
# 3                    NaN
# 4                    NaN

# %%
print(atck['Year'].describe())
print('')
print(atck['Year'].value_counts())
# Out:
# count     6698.0
# unique     253.0
# top       2015.0
# freq       143.0
# Name: Year, dtype: float64
#
# 2015.0    143
# 2017.0    139
# 2016.0    131
# 0.0       129
# 2011.0    128
#          ...
# 1792.0      1
# 1791.0      1
# 1788.0      1
# 1787.0      1
# 1753.0      1
# Name: Year, Length: 253, dtype: int64

# %% [markdown]
# ### Criar um DataFrame apenas com os dados dos últimos 20 anos de ataques de tubarões no mundo.

# %%
year_2000 = atck['Year'] > 2000
print(year_2000)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25822    False
# 25823    False
# 25824    False
# 25825    False
# 25826    False
# Name: Year, Length: 25827, dtype: bool

# %%
atck['Year'] < 2000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c9958ef0fdb> in <module>
# ----> 1 atck['Year'] < 2000
#
# NameError: name 'atck' is not defined

# %%
atck = (atck[atck['Year'] > 2000])

# %%
atck
# Out:
#         Year        Type                     Country              Area  \
# 0     2021.0         NaN                       EGYPT               NaN
# 1     2021.0  Unprovoked                         USA           Florida
# 2     2021.0  Unprovoked                   AUSTRALIA   New South Wales
# 3     2021.0  Unprovoked  British Overseas Territory  Turks and Caicos
# 4     2021.0  Unprovoked                         USA             Texas
# ...      ...         ...                         ...               ...
# 2354  2001.0  Watercraft                   AUSTRALIA   New South Wales
# 2355  2001.0  Unprovoked                        CUBA  Holquin Province
# 2356  2001.0  Watercraft                   AUSTRALIA   South Australia
# 2357  2001.0  Unprovoked                         USA        California
# 2358  2001.0  Watercraft                 NEW ZEALAND      North Island
#
#              Activity Sex   Age  \
# 0            Swimming    M  NaN
# 1             Surfing    M   !6
# 2             Surfing    M   31
# 3                 NaN    M  NaN
# 4     Boogie boarding    M   !!
# ...               ...  ...  ...
# 2354         Kayaking    M   35
# 2355         Swimming    F   55
# 2356          Fishing  NaN  NaN
# 2357          Surfing    M  NaN
# 2358         Kayaking    M  NaN
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0              Laceration to arm caused by metal object         NaN    NaN
# 1                             Minor injury to right arm           N  13h20
# 2                                                 FATAL           Y  10h30
# 3                                          Wrist bitten           N    NaN
# 4     Lacerations both sides of lower leg immediatel...           N  11h45
# ...                                                 ...         ...    ...
# 2354                No injury, shark rammed & bit kayak           N    NaN
# 2355                                    Left arm bitten           N    NaN
# 2356                             No injury to occupants           N    NaN
# 2357                         Foot bruised, board dinged           N    NaN
# 2358                            No injury, kayak bitten           N    NaN
#
#                                             Species
# 0                              No shark invovlement
# 1                                                NaN
# 2                                        White xhark
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2354                                       5 m shark
# 2355                               2 m [6.75'] shark
# 2356                       White shark, 4.3 m [14']
# 2357  1.8 m to 2.4 m [6' to 8'] "black finned shark"
# 2358                                     White shark
#
# [2358 rows x 11 columns]

# %%
atck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2358 entries, 0 to 2358
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         2358 non-null   object
#  1   Type         2347 non-null   object
#  2   Country      2356 non-null   object
#  3   Area         2257 non-null   object
#  4   Activity     2252 non-null   object
#  5   Sex          2256 non-null   object
#  6   Age          1771 non-null   object
#  7   Injury       2353 non-null   object
#  8   Fatal (Y/N)  2192 non-null   object
#  9   Time         1710 non-null   object
#  10  Species      1514 non-null   object
# dtypes: object(11)
# memory usage: 221.1+ KB

# %% [markdown]
# ### Criar um DataFrame com os acidentes registrados entre 1990 e 2020.

# %%
# Para reinicar tudo que foi feito acima, utilizar essa célula.
import pandas as pd
import numpy as np

atck_xls = pd.read_excel('Datas/GSAF5.xls')

atck = (atck_xls['Year'], atck_xls['Type'], atck_xls['Country'], atck_xls['Area'],
        atck_xls['Activity'],atck_xls['Sex '], atck_xls['Age'], atck_xls['Injury'],
        atck_xls['Fatal (Y/N)'], atck_xls['Time'], atck_xls['Species '])

atck = pd.DataFrame(atck)
atck = atck.transpose()

# Transformar a coluna 'Year' (nossa variável chave), de object para float
atck['Year'] = atck['Year'].astype(float, errors = 'raise')

# A primeira linha está classificado como 'No Shark involvement', vou deletar. 
# IMPORTANTE: depois ver se tem mais 'No Shark involvement' na coluna 'Injury'!!!
atck = atck.drop(0, axis = 0)
atck = atck.reset_index(drop = True)

atck.head()
# Out:
#      Year        Type                     Country              Area  \
# 0  2021.0  Unprovoked                         USA           Florida
# 1  2021.0  Unprovoked                   AUSTRALIA   New South Wales
# 2  2021.0  Unprovoked  British Overseas Territory  Turks and Caicos
# 3  2021.0  Unprovoked                         USA             Texas
# 4  2021.0  Unprovoked                         USA         Louisiana
#
#                  Activity Sex   Age  \
# 0                 Surfing    M   !6
# 1                 Surfing    M   31
# 2                     NaN    M  NaN
# 3         Boogie boarding    M   !!
# 4  Fishing, fell in water    M   64
#
#                                               Injury Fatal (Y/N)   Time  \
# 0                          Minor injury to right arm           N  13h20
# 1                                              FATAL           Y  10h30
# 2                                       Wrist bitten           N    NaN
# 3  Lacerations both sides of lower leg immediatel...           N  11h45
# 4                               Severe injury to leg           N  14h00
#
#       Species
# 0          NaN
# 1  White xhark
# 2          NaN
# 3          NaN
# 4          NaN

# %%
atck90 = atck[atck['Year'] > 1990]
atck20 = atck[atck['Year'] < 2021]

atck = pd.concat([atck20, atck90], ignore_index = True)
atck
# Out:
#          Year        Type       Country                   Area  \
# 0      2020.0  Unprovoked           USA             California
# 1      2020.0  Unprovoked      MALDIVES              Raa Atoll
# 2      2020.0  Unprovoked     ST MARTIN                    NaN
# 3      2020.0  Unprovoked     AUSTRALIA      Western Australia
# 4      2020.0  Unprovoked           USA                 Hawaii
# ...       ...         ...           ...                    ...
# 26964  1991.0  Unprovoked           USA                 Oregon
# 26965  1991.0  Unprovoked  SOUTH AFRICA  Western Cape Province
# 26966  1991.0  Unprovoked     AUSTRALIA             Queensland
# 26967  1991.0  Unprovoked     AUSTRALIA      Western Australia
# 26968  1991.0  Unprovoked     AUSTRALIA             Queensland
#
#                         Activity Sex   Age                            Injury  \
# 0                       Swimming    M  NaN       No injury. Swim fin bittten
# 1          Fell off fishing boat    M   40                   Injuries to leg
# 2                       Swimming    F   39                             FATAL
# 3                        Surfing    M  NaN           No injury, Board bitten
# 4                        Surfing    M   56                             FATAL
# ...                          ...  ...  ...                               ...
# 26964                    Surfing    M   38     Calf lacerated & board bitten
# 26965               Spearfishing    M   20            Foot & swim fin bitten
# 26966                   Swimming    M   35  Hands, legs & buttocks lacerated
# 26967                Surf-skiing    M  NaN      No injury, shark brushed ski
# 26968  Surfing (or sailboarding)    M   22                          Survived
#
#       Fatal (Y/N)       Time                 Species
# 0               N  Afternoon              White shark
# 1               N      09h36                      NaN
# 2               Y      14h00              Tiger shark
# 3               N      07h00                      NaN
# 4               Y      07h45       Tiger shark. 14'3"
# ...           ...        ...                      ...
# 26964           N      09h30  5.5 m [18'] white shark
# 26965           N      12h30  5.5 m [18'] white shark
# 26966           N      08h10                      NaN
# 26967           N        NaN                4 m shark
# 26968           N        NaN                2 m shark
#
# [26969 rows x 11 columns]

# %%
# Continuar daqui. o DataFrame atck já está filtrados
# pelos ataques realizados em 1990 e 2020
atck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26969 entries, 0 to 26968
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         26969 non-null  float64
#  1   Type         26892 non-null  object
#  2   Country      26905 non-null  object
#  3   Area         25644 non-null  object
#  4   Activity     25427 non-null  object
#  5   Sex          25268 non-null  object
#  6   Age          18720 non-null  object
#  7   Injury       26895 non-null  object
#  8   Fatal (Y/N)  25032 non-null  object
#  9   Time         17224 non-null  object
#  10  Species      16877 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 2.3+ MB
