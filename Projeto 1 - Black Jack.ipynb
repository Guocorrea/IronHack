# %%
# cadastrar cada jogador
Jogador_1 = str(input('Jogador 1, insera seu nome de jogador(a): '))
Jogador_2 = str(input('Jogador 2, insera seu nome de jogador(a): '))

while (Jogador_1 == Jogador_2):
    print('Jogador 2, esse nome de jogador já existe. Por favor, insira um novo nome.')
    Jogador_2 = str(input('Jogador 2, insera seu nome de jogador(a): '))
print('-'*115)

# Criar baralho

criar_baralho = ['Ás', 'Dois', 'Três', 'Quatro', 'Cinco', 'Seis', 'Sete', 'Oito', 'Nove', 'Dez', 'Valete', 'Dama', 'Rei']
cartas_ouro = list()

for i in criar_baralho:
    a = i + ' de Ouros'
    cartas_ouro.append(a)

baralho = dict()
value = 0

for item in cartas_ouro:
    value += 1
    baralho[item] = value
    if value >= 10:
        value = 9

cartas_paus = list()
value = 0

for i in criar_baralho:
    a = i + ' de Paus'
    cartas_paus.append(a)

for item in cartas_paus:
    value += 1
    baralho[item] = value
    if value >= 10:
        value = 9

cartas_copas = list()
value = 0

for i in criar_baralho:
    a = i + ' de Copas'
    cartas_copas.append(a)

for item in cartas_copas:
    value += 1
    baralho[item] = value
    if value >= 10:
        value = 9
    
cartas_espadas = list()
value = 0

for i in criar_baralho:
    a = i + ' de Espadas'
    cartas_espadas.append(a)

for item in cartas_espadas:
    value += 1
    baralho[item] = value
    if value >= 10:
        value = 9
        
# Criar uma variável global para a mão de cada jogador
mao_j1 = list()
mao_j2 = list()

# Criar a 'mão' de cada jogador

import random

while len(mao_j1) < 2:
    carta = random.choice(list(baralho.keys()))
    if carta not in mao_j1 and carta not in mao_j2:
        mao_j1.append(carta)
        
while len(mao_j2) < 2:
    carta = random.choice(list(baralho.keys()))
    if carta not in mao_j1 and carta not in mao_j2:
        mao_j2.append(carta)
        
        
print(f'''{Jogador_1}: {' / '.join(mao_j1)}
{Jogador_2}: {' / '.join(mao_j2)}''')

print('-'*115)

# Criar uma função para cada jogador para dar mais uma carta para cada um

def play1():
    '''Essa função vai sortear uma carta aleatória para o jogador 1 e chamar a função points1'''
    
    global outra_carta_1
    global outra_carta_2
    carta = random.choice(list(baralho.keys()))
    if carta not in mao_j1 and carta not in mao_j2:
        mao_j1.append(carta)
        return points1()
    else:
        return play1()

def play2():
    '''Essa função vai sortear uma carta aleatória para o jogador 2 e chamar a função points2'''
    
    global outra_carta_1
    global outra_carta_2
    carta = random.choice(list(baralho.keys()))
    if carta not in mao_j1 and carta not in mao_j2:
        mao_j2.append(carta)
        return points2()
    else:
        return play2()

# Criar variável global para o pontos nas mão de cada jogador
p1_pont = int()
p2_pont = int()

# Criar um função para contagem de pontos das cartas nas mãos dos jogadores

def contagem():
    '''Fazer a contagem das cartas de cada mão'''
    global p1_pont
    global p2_pont
    p1_pont = 0
    p2_pont = 0
    for a in mao_j1:
        p1_pont += baralho[a]
    for b in mao_j2:
        p2_pont += baralho[b]
    return p1_pont, p2_pont

# Criar uma função para contar as cartas na mão de cada jogador e retornar o resultado

def points1():
    '''Fazer a contagem de pontos da mão do jogador 1 e retornar o resultado para a mesa.
    se o jogador1 estourar a mão essa função termina o jogo.
    Senão avalia a condição de outra_carta_2:
    se 'S' = chama a função comprar_carta2() / se 'N' chama a função comprar_carta1() '''
   
    contagem()
    if p1_pont > 21:
        return print(f'''{'-'*127}
        {Jogador_1}, sua mão: {' / '.join(mao_j1)}. você fez {p1_pont} pontos.
        {Jogador_2} venceu!!''')
    else:
        print(f'''Suas cartas {Jogador_1}: {' / '.join(mao_j1)}.''')
        print('-'*115)
        if outra_carta_2 == 'N' or outra_carta_2 == 'n':
            return comprar_carta1()
        elif outra_carta_2 == 'S' or outra_carta_2 == 's':
            return comprar_carta2()
        
def points2():
    '''Mesma função do points(1), mas para o jogador2'''
    
    contagem()
    if p2_pont > 21:
        return print(f'''{'-'*127}
        {Jogador_2}, sua mão: {' / '.join(mao_j2)}. Você fez {p2_pont} pontos. 
        {Jogador_1} venceu!!''')
    else:
        print(f'''Suas cartas {Jogador_2}: {' / '.join(mao_j2)}''')
        print('-'*115)
        if outra_carta_1 == 'N' or outra_carta_1 == 'n':
            return comprar_carta2()
        elif outra_carta_1 == 'S' or outra_carta_1 == 's':
            return comprar_carta1()

# Criar variável global que diz se o jogador quer outra carta ou não (S / N)
outra_carta_1 = str
outra_carta_2 = 'S'

# Criar fórmula para definir se o jogador que comprar mais um carta ou não        
        
def comprar_carta1():
    '''Pergunte se o jogador 1 quer comprar uma carta e coloca uma str 'S' ou 'N' na variável outra_carta_1.
    Se 'S' chama a função play1().
    Se 'N', avalia a condição da variável outra_carta_2 do Jogador 2. 
    Se jogador 2 for 'S', chama a função comprar_carta2() / Se 'N', chama a função fim()'''
    
    global outra_carta_1
    global outra_carta_2
    outra_carta_1 = str(input(f'''{Jogador_1}, você tem na mão: {' / '.join(mao_j1)}.
    Deseja comprar mais um carta? (Responda com S ou N)'''))
    if outra_carta_1 == 's':
        None
    elif outra_carta_1 == 'S':
        None
    elif outra_carta_1 == 'n':
        None
    elif outra_carta_1 == 'N':
        None
    else:
        print('')
        print('Erro de código!!! Por favor, insira S para comprar nova carta ou N para passar a vez')
        outra_carta_1 = str(input(f'''Gustavo:
        Deseja comprar mais um carta? (Responda com S ou N)'''))
    print('-'*115)
    
    if outra_carta_1 == "s" or outra_carta_1 == "S":
        return play1()
    elif outra_carta_1 == "n" or outra_carta_1 == "N":
        if outra_carta_2 == "s" or outra_carta_2 == "S":
            return comprar_carta2()
        elif outra_carta_2 == "n" or outra_carta_2 == "N":
            return fim()
        
def comprar_carta2(): # FAZER ISSO AQUI!!!!!!!! IGUAL DE CIMA
    '''Pergunte se o jogador 2 quer comprar uma carta. Se sim, roda play2; se não, roda comprar_carta1.
    As 4 funções play1, play2, comprar_carta1 e comprar_carta2 vão ficar rodando entre elas até que 
    um dos jogadores estoure a mão ou os dois jogadores falarem que não querem comprar mais uma carta'''
    
    global outra_carta_2
    global outra_carta_1
    outra_carta_2 = str(input(f'''{Jogador_2}, você tem na mão: {' / '.join(mao_j2)}.
    Deseja comprar mais um carta? (Responda com S ou N)'''))
    if outra_carta_2 == 'S' or outra_carta_2 == 's':
        return play2()
    elif outra_carta_2 == "n" or outra_carta_2 == "N":
        if outra_carta_1 == "s" or outra_carta_1 == "S":
            return comprar_carta1()
        elif outra_carta_1 == "n" or outra_carta_1 == "N":
            return fim()     
             
# Criar uma função para ver se o jogo acabou

def fim():
    contagem()
    if p1_pont > p2_pont:
        return print(f'''{Jogador_1} fez {p1_pont} e {Jogador_2} fez {p2_pont}.
        {Jogador_1} venceu!
        FIM DE JOGO.''')
    elif p2_pont > p1_pont:
        return print (f'''{Jogador_2} fez {p2_pont} e {Jogador_1} fez {p1_pont}.
        {Jogador_2} venceu!
        FIM DE JOGO.''')
    else:
        return print(f'''{Jogador_1} fez {p1_pont} e {Jogador_2} fez {p2_pont}.
        Vocês emparatam.
        FIM DE JOGO''')
    
comprar_carta1()
# Out:
# Jogador 1, insera seu nome de jogador(a): Gustavo
# Jogador 2, insera seu nome de jogador(a): Juka
# -------------------------------------------------------------------------------------------------------------------
# Gustavo: Seis de Ouros / Dois de Paus
# Juka: Rei de Copas / Nove de Espadas
# -------------------------------------------------------------------------------------------------------------------
# Gustavo, você tem na mão: Seis de Ouros / Dois de Paus.
#     Deseja comprar mais um carta? (Responda com S ou N)s
# -------------------------------------------------------------------------------------------------------------------
# Suas cartas Gustavo: Seis de Ouros / Dois de Paus / Cinco de Copas.
# -------------------------------------------------------------------------------------------------------------------
# Juka, você tem na mão: Rei de Copas / Nove de Espadas.
#     Deseja comprar mais um carta? (Responda com S ou N)n
# ...

# %%
print(baralho)
